# %% [markdown]
# # Gassian Distribution

# %% [markdown]
# High school should have introduced you the single variable Gaussian distribution, or what we usually call, normal distribution.
#
# TODO: Insert generic formula here

# %%
# importing packages
import numpy as np
import matplotlib.pyplot as plt

# %%
samples = np.random.randn(50)
print samples
# Out:
# [-0.11756046 -0.49984414  0.41957393  0.81404493  0.43989031 -0.75312847
#  -1.13369028  0.14628723  0.43883687  0.34726631 -0.37488278  1.86912515
#  -1.57775092 -0.65893005  1.49787387 -2.45802573  1.26166574 -1.23129213
#  -0.7362085   0.31270165  2.05622401  1.14690016 -0.80377503 -0.46752815
#   0.46882033  0.13916572  0.78805749 -0.96493121  1.93267759  0.47133499
#  -0.77337388  0.26671196 -0.60991414  0.49434646  1.19116417  0.30957825
#   0.1692673   0.55811943 -0.12205735  0.9252746  -0.79639665  0.32915575
#   0.64964571  2.05044579  0.29129276  0.39136721  1.58056018 -1.20491263
#   0.35025227  0.14112464]

# %%
plt.figure(figsize=(15,3))
plt.scatter(samples,[0]*len(samples))
plt.xlim([-5,5])
plt.title("sampling standard normal distribution ")
plt.show()

# %% [markdown]
# TODO: Insert formula here

# %%
plt.figure(figsize=(16,3))
plt.plot(np.arange(-5,5,0.01),[1/np.sqrt(2) * np.exp(-(x**2)) for x in np.arange(-5,5,0.01)])
# plot histogram here
plt.xlim([-5,5])
plt.title("sampling standard normal distribution")
plt.show()

# %% [markdown]
# ### Normal distribution with different mean

# %%
mean = 1
samples = np.random.randn(50) + mean

# %%
plt.figure(figsize=(16,3))
plt.scatter(samples,[0]*len(samples))
plt.xlim([-5,5])
plt.title("sampling normal distribution with different mean")
plt.show()

# %% [markdown]
# TODO: Insert formula here

# %%
plt.figure(figsize=(16,3))
plt.plot(np.arange(-5,5,0.01),[1/np.sqrt(2) * np.exp(-((x-mean)**2)) for x in np.arange(-5,5,0.01)])
# plot histogram here
plt.xlim([-5,5])
plt.title("sampling standard normal distribution ")
plt.show()

# %% [markdown]
# ### Normal distribution with different mean and variance

# %%
mean = 1
std_dev = 2
samples = std_dev*np.random.randn(50) + mean
print samples
# Out:
# [-0.3199104  -0.77150767  1.95177318 -0.80613384  5.93810265  1.92584461
#   2.38577882  0.85128033  0.84386925 -1.13503779  1.01292545  0.72925798
#   2.27751361 -2.14105713 -0.76276657  1.22451886  0.83108545  0.49561919
#   1.78586179  2.30309896 -1.17697917  1.78895732  1.03271601  2.11935534
#  -2.16076281  3.25892596  4.47607734  1.43504722 -0.08834288  1.44906113
#  -1.95846607  1.89290868 -3.20726013 -0.59699694 -1.79832278 -0.37297377
#   0.4871549  -0.25767646  1.05608346  3.75872925  3.28499121 -0.91415361
#   5.11607789  1.6429964   5.93224445 -0.56505932  1.98535546 -1.73384348
#   4.65378702 -2.23599317]

# %%
plt.figure(figsize=(16,3))
plt.scatter(samples,[0]*len(samples))
plt.xlim([-5,5])
plt.title("sampling normal distribution with different mean and variance")
plt.show()

# %% [markdown]
# TODO: Insert formula here

# %%
plt.figure(figsize=(16,3))
plt.plot(np.arange(-5,5,0.01),[1/np.sqrt(2*std_dev) * np.exp(-((x-mean)/std_dev)**2) for x in np.arange(-5,5,0.01)])
# plot histogram here
plt.xlim([-5,5])
plt.title("pdf of normal distribution with different mean and variance")
plt.show()

# %% [markdown]
# ## Multivariate Gaussian distribution
